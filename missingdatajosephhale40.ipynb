# %% [markdown]
# <a href="https://colab.research.google.com/github/josephhalejr/Sales/blob/main/missingdatajosephhale40.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
('/content/RailsToTrails_National Count Data_week (7) (2) (1).xlsx')
# Out:
# '/content/RailsToTrails_National Count Data_week (7) (2) (1).xlsx'

# %%
import pandas as pd
import numpy as np
import random

# %%
bike_df = ('/content/RailsToTrails_National Count Data_week (7) (2) (1).xlsx')

# %%
df = pd.read_excel(bike_df)

# %%
df.head()
# Out:
#   Timeframe    Week of  ...  Unnamed: 8  Unnamed: 9
# 0    Week 1 2020-12-30  ...         NaN         NaN
# 1    Week 2 2020-01-06  ...         NaN         NaN
# 2    Week 3 2020-01-13  ...         NaN         NaN
# 3    Week 4 2020-01-20  ...         NaN         NaN
# 4    Week 5 2020-01-27  ...         NaN         NaN
#
# [5 rows x 10 columns]

# %% [markdown]
# # delete unnamed columns Unnamed: 7 Unammed: 8 Unnamed 9

# %%
del df['Unnamed: 7']

# %%
del df['Unnamed: 8']

# %%
del df['Unnamed: 9']

# %%
df.head()
# Out:
#   Timeframe    Week of  ...  Change 2019-2020  Unnamed: 6
# 0    Week 1 2020-12-30  ...          0.094627    1.094627
# 1    Week 2 2020-01-06  ...          0.179743  117.974253
# 2    Week 3 2020-01-13  ...          0.216112  121.611169
# 3    Week 4 2020-01-20  ...          0.105645  110.564504
# 4    Week 5 2020-01-27  ...          0.249166  124.916602
#
# [5 rows x 7 columns]

# %% [markdown]
# # renaming the unnamed column 6 to percent_change

# %%
df = df.rename(columns={'Unnamed: 6': 'percent_change'})
df.head()
# Out:
#   Timeframe    Week of  ...  Change 2019-2020  percent_change
# 0    Week 1 2020-12-30  ...          0.094627        1.094627
# 1    Week 2 2020-01-06  ...          0.179743      117.974253
# 2    Week 3 2020-01-13  ...          0.216112      121.611169
# 3    Week 4 2020-01-20  ...          0.105645      110.564504
# 4    Week 5 2020-01-27  ...          0.249166      124.916602
#
# [5 rows x 7 columns]

# %% [markdown]
# # fill in the missing data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Timeframe                   52 non-null     object
#  1   Week of                     52 non-null     datetime64[ns]
#  2    2019 counts (31 counters)  52 non-null     int64
#  3    2020 counts (31 counters)  52 non-null     int64
#  4   2021 Counts                 0 non-null      float64
#  5   Change 2019-2020            52 non-null     float64
#  6   percent_change              52 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 3.0+ KB

# %%
df.fillna(0)
# Out:
#    Timeframe    Week of  ...  Change 2019-2020  percent_change
# 0     Week 1 2020-12-30  ...          0.094627        1.094627
# 1     Week 2 2020-01-06  ...          0.179743      117.974253
# 2     Week 3 2020-01-13  ...          0.216112      121.611169
# 3     Week 4 2020-01-20  ...          0.105645      110.564504
# 4     Week 5 2020-01-27  ...          0.249166      124.916602
# 5     Week 6 2020-02-03  ...          0.924731      192.473051
# 6     Week 7 2020-02-10  ...          0.983068      198.306761
# 7     Week 8 2020-02-17  ...          1.156737      215.673747
# 8     Week 9 2020-02-24  ...          0.648422      164.842218
# 9    Week 10 2020-03-02  ...          0.982298      198.229837
# 10   Week 11 2020-03-09  ...          0.946220      194.621973
# 11   Week 12 2020-03-16  ...          1.932039      293.203922
# 12   Week 13 2020-03-23  ...          1.730000      273.441649
# 13   Week 14 2020-03-30  ...          1.360000      236.334860
# ...
